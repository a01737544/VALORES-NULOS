# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga de un archivo .xlsx desde un libro con varias páginas 
df= pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2023', skiprows=3)
df
# Out:
#          Fecha       Folio                                  UUID  \
# 0   2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1   2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2   2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3   2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4   2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..         ...         ...                                   ...
# 392 2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393 2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394 2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395 2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396 2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# ...

# %%
#Identificar valores nulos por columna
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio           13
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       8
# Descripción      0
# MP              71
# FP              71
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Identificar valores nulos por dataframe
valores_nulos=df.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(675)

# %%
#Realizamos una copia del dataframe
df1 = df.copy()

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df1["Folio"]=df1["Folio"].fillna(method="ffill")
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_624\1765622335.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1["Folio"]=df1["Folio"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       8
# Descripción      0
# MP              71
# FP              71
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df1["TIPO GASTO"] =df1["TIPO GASTO"].fillna("No registrado")

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP              71
# FP              71
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
df1["FP"]= df1["FP"].fillna(00) 
df1
# Out:
#          Fecha       Folio                                  UUID  \
# 0   2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1   2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2   2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3   2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4   2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..         ...         ...                                   ...
# 392 2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393 2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394 2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395 2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396 2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP              71
# FP               0
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df1["MP"] =df1["MP"].fillna("Pago")

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP               0
# FP               0
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Sexto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df1["Poliza"] =df1["Poliza"].fillna(method="bfill")
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_624\4049845603.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1["Poliza"] =df1["Poliza"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP               0
# FP               0
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza           8
# dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
df1["Poliza"] =df1["Poliza"].fillna("Pue")

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha          0
# UUID           0
# RFC            0
# Proveedor      0
# Descripción    0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# Tipo           0
# Status         0
# dtype: int64

# %%
#Eliminamos filas con nulos
#No se agrega nada para eliminar filas y 1 para eliminar columnas
df1= df.dropna(axis=1)
df1
# Out:
#          Fecha                                  UUID           RFC  \
# 0   2023-01-01  49536321-60A4-523E-A32F-E8BDF5C2276E  AAE6411055P8
# 1   2023-01-01  20FBB63B-D550-512F-9668-EEC6F983CEB7  AAE6411055P8
# 2   2023-01-01  DB8C4388-D4E0-4F0C-A09C-77C773257F44  BLE1512082R9
# 3   2023-01-01  A81A63F5-D5EC-4601-803E-375AF9CC5021  BLE1512082R9
# 4   2023-01-01  DCC10492-DE51-4C87-8430-5676FBF81931  BLE1512082R9
# ..         ...                                   ...           ...
# 392 2023-02-01  3E97C399-6747-4BCA-8436-ED4B0933DF33  BIN940223KE0
# 393 2023-02-01  B7132758-F800-4797-B1D6-CC61AFFEE444  BPU7901018D4
# 394 2023-02-01  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7  BMN930209927
# 395 2023-02-01  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1  EFE8908015L3
# 396 2023-02-01  439A9230-277E-5563-818C-7630B0E8D706  AAE6411055P8
#
#                                              Proveedor  \
# 0                            AESA ARTICULOS ELECTRICOS
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Fecha          0
# UUID           0
# RFC            0
# Proveedor      0
# Descripción    0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# Tipo           0
# Status         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        397 non-null    datetime64[ns]
#  1   Folio        384 non-null    object
#  2   UUID         397 non-null    object
#  3   RFC          397 non-null    object
#  4   Proveedor    397 non-null    object
#  5   TIPO GASTO   389 non-null    object
#  6   Descripción  397 non-null    object
#  7   MP           326 non-null    object
#  8   FP           326 non-null    float64
#  9   TC           397 non-null    float64
#  10  Importe      397 non-null    float64
#  11  IVA          397 non-null    float64
#  12  RET ISR      397 non-null    float64
#  13  RET IVA      397 non-null    float64
#  14  Otros        0 non-null      float64
#  15  TOTAL MX     397 non-null    float64
#  16  TOTAL SAT    397 non-null    float64
#  17  Tipo         397 non-null    object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        397 non-null    datetime64[ns]
#  1   UUID         397 non-null    object
#  2   RFC          397 non-null    object
#  3   Proveedor    397 non-null    object
#  4   Descripción  397 non-null    object
#  5   TC           397 non-null    float64
#  6   Importe      397 non-null    float64
#  7   IVA          397 non-null    float64
#  8   RET ISR      397 non-null    float64
#  9   RET IVA      397 non-null    float64
#  10  TOTAL MX     397 non-null    float64
#  11  TOTAL SAT    397 non-null    float64
#  12  Tipo         397 non-null    object
#  13  Status       397 non-null    object
# dtypes: datetime64[ns](1), float64(7), object(6)
# memory usage: 43.6+ KB

# %%
#Convertir DataFrame a xlsx
df1.to_csv("gastos_costos_correcto.csv")
